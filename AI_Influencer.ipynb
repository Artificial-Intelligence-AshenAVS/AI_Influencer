# %%
# !pip install pygit2==1.12.2
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# !python entry_with_update.py --share
# Out:
# Requirement already satisfied: pygit2==1.12.2 in /usr/local/lib/python3.10/dist-packages (1.12.2)
# Requirement already satisfied: cffi>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from pygit2==1.12.2) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.9.1->pygit2==1.12.2) (2.21)
# /content
# fatal: destination path 'Fooocus' already exists and is not an empty directory.
# /content/Fooocus
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share']
# Python 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# Fooocus version: 2.1.862
# Running on local URL:  http://127.0.0.1:7865
# Running on public URL: https://986d9e2e0ef4972528.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# Total VRAM 15102 MB, total RAM 12979 MB
# Set vram state to: NORMAL_VRAM
# Always offload VRAM
# Device: cuda:0 Tesla T4 : native
# VAE dtype: torch.float32
# Using pytorch cross attention
# 2024-01-11 05:15:45.280822: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-11 05:15:45.280931: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-11 05:15:45.382985: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-11 05:15:47.500603: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Refiner unloaded.
# model_type EPS
# UNet ADM Dimension 2816
# Using pytorch attention in VAE
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# Using pytorch attention in VAE
# extra {'cond_stage_model.clip_l.text_projection', 'cond_stage_model.clip_g.transformer.text_model.embeddings.position_ids', 'cond_stage_model.clip_l.logit_scale'}
# Base model loaded: /content/Fooocus/models/checkpoints/juggernautXL_version6Rundiffusion.safetensors
# Request to load LoRAs [['sd_xl_offset_example-lora_1.0.safetensors', 0.1], ['None', 1.0], ['None', 1.0], ['None', 1.0], ['None', 1.0]] for model [/content/Fooocus/models/checkpoints/juggernautXL_version6Rundiffusion.safetensors].
# Loaded LoRA [/content/Fooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors] for UNet [/content/Fooocus/models/checkpoints/juggernautXL_version6Rundiffusion.safetensors] with 788 keys at weight 0.1.
# Fooocus V2 Expansion: Vocab with 642 words.
# Fooocus Expansion engine loaded for cuda:0, use_fp16 = True.
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.81 seconds
# App started successful. Use the app with http://127.0.0.1:7865/ or 127.0.0.1:7865 or https://986d9e2e0ef4972528.gradio.live
# [Parameters] Adaptive CFG = 7
# [Parameters] Sharpness = 2
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] CFG = 4.0
# [Parameters] Seed = 7268186747419204588
# [Fooocus] Downloading control models ...
# [Fooocus] Loading control models ...
# extra clip vision: ['vision_model.embeddings.position_ids']
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 30 - 15
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.15 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Fooocus] Image processing ...
# Detected 1 faces
# Requested to load CLIPVisionModelWithProjection
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.91 seconds
# Requested to load Resampler
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.59 seconds
# Requested to load To_KV
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.32 seconds
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (896, 1152)
# Preparation time: 25.75 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 2.51 seconds
# 100% 30/30 [00:33<00:00,  1.11s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.37 seconds
# Image generated with private log at: /content/Fooocus/outputs/2024-01-11/log.html
# Generating and saving time: 41.14 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 3.08 seconds
# 100% 30/30 [00:31<00:00,  1.04s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.36 seconds
# Image generated with private log at: /content/Fooocus/outputs/2024-01-11/log.html
# Generating and saving time: 38.92 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 1.42 seconds
# Total time: 111.10 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] Sharpness = 2
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] CFG = 4.0
# [Parameters] Seed = 1967318493393442121
# [Fooocus] Downloading control models ...
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 30 - 15
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.14 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding positive #3 ...
# [Fooocus] Encoding positive #4 ...
# [Fooocus] Encoding positive #5 ...
# [Fooocus] Encoding positive #6 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Fooocus] Encoding negative #3 ...
# [Fooocus] Encoding negative #4 ...
# [Fooocus] Encoding negative #5 ...
# [Fooocus] Encoding negative #6 ...
# [Fooocus] Image processing ...
# Detected 1 faces
# Requested to load CLIPVisionModelWithProjection
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.24 seconds
# Requested to load Resampler
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.69 seconds
# Requested to load To_KV
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 85.04 seconds
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (896, 1152)
# Preparation time: 244.76 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 2.33 seconds
# 100% 30/30 [00:33<00:00,  1.11s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.39 seconds
# Image generated with private log at: /content/Fooocus/outputs/2024-01-11/log.html
# Generating and saving time: 41.20 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 2.06 seconds
# 100% 30/30 [01:02<00:00,  2.08s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.41 seconds
# Image generated with private log at: /content/Fooocus/outputs/2024-01-11/log.html
# Generating and saving time: 69.70 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 2.44 seconds
# 100% 30/30 [01:08<00:00,  2.28s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.40 seconds
# Image generated with private log at: /content/Fooocus/outputs/2024-01-11/log.html
# Generating and saving time: 76.35 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 2.49 seconds
# 100% 30/30 [00:38<00:00,  1.29s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.35 seconds
# Image generated with private log at: /content/Fooocus/outputs/2024-01-11/log.html
# Generating and saving time: 46.15 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 3.20 seconds
# 100% 30/30 [00:31<00:00,  1.04s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.33 seconds
# Image generated with private log at: /content/Fooocus/outputs/2024-01-11/log.html
# Generating and saving time: 39.52 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 2.19 seconds
# 100% 30/30 [00:31<00:00,  1.05s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.42 seconds
# Image generated with private log at: /content/Fooocus/outputs/2024-01-11/log.html
# Generating and saving time: 38.79 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 1.02 seconds
# Total time: 569.76 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] Sharpness = 2
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] CFG = 4.0
# [Parameters] Seed = 6513709653443318136
# [Fooocus] Downloading control models ...
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 30 - 15
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.14 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding positive #3 ...
# [Fooocus] Encoding positive #4 ...
# [Fooocus] Encoding positive #5 ...
# [Fooocus] Encoding positive #6 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Fooocus] Encoding negative #3 ...
# [Fooocus] Encoding negative #4 ...
# [Fooocus] Encoding negative #5 ...
# [Fooocus] Encoding negative #6 ...
# [Fooocus] Image processing ...
# Detected 1 faces
# Requested to load CLIPVisionModelWithProjection
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.41 seconds
# Requested to load Resampler
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.60 seconds
# Requested to load To_KV
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.27 seconds
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (896, 1152)
# Preparation time: 7.96 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 2.25 seconds
# 100% 30/30 [00:32<00:00,  1.08s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.35 seconds
# Image generated with private log at: /content/Fooocus/outputs/2024-01-11/log.html
# Generating and saving time: 39.21 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 2.00 seconds
# 100% 30/30 [00:31<00:00,  1.04s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.39 seconds
# Image generated with private log at: /content/Fooocus/outputs/2024-01-11/log.html
# Generating and saving time: 37.88 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 2.40 seconds
# 100% 30/30 [00:31<00:00,  1.05s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.34 seconds
# Image generated with private log at: /content/Fooocus/outputs/2024-01-11/log.html
# Generating and saving time: 38.58 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 2.00 seconds
# 100% 30/30 [00:31<00:00,  1.05s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.35 seconds
# Image generated with private log at: /content/Fooocus/outputs/2024-01-11/log.html
# Generating and saving time: 38.31 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 2.02 seconds
# 100% 30/30 [00:31<00:00,  1.05s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.35 seconds
# Image generated with private log at: /content/Fooocus/outputs/2024-01-11/log.html
# Generating and saving time: 38.43 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 2.81 seconds
# 100% 30/30 [00:31<00:00,  1.05s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.34 seconds
# Image generated with private log at: /content/Fooocus/outputs/2024-01-11/log.html
# Generating and saving time: 39.56 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 1.73 seconds
# Total time: 253.37 seconds
# Keyboard interruption in main thread... closing server.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 2199, in block_thread
#     time.sleep(0.1)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/Fooocus/entry_with_update.py", line 46, in <module>
#     from launch import *
#   File "/content/Fooocus/launch.py", line 109, in <module>
#     from webui import *
#   File "/content/Fooocus/webui.py", line 616, in <module>
#     shared.gradio_root.launch(
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 2115, in launch
#     self.block_thread()
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 2203, in block_thread
#     self.server.close()
#   File "/usr/local/lib/python3.10/dist-packages/gradio/networking.py", line 49, in close
#     self.thread.join()
#   File "/usr/lib/python3.10/threading.py", line 1096, in join
#     self._wait_for_tstate_lock()
#   File "/usr/lib/python3.10/threading.py", line 1116, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
# KeyboardInterrupt
# Killing tunnel 127.0.0.1:7865 <> https://986d9e2e0ef4972528.gradio.live
